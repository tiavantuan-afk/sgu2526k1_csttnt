# %% [markdown]
# # "Thuc hanh tri tue nhan tao Buoi 1"
# ## "Noi dung thuc hanh"

# %% [markdown]
# #### In chu ra man hinh

# %%
#Lenh 1 - xuat chu
print("Hello, Python World")
# Out:
# Hello, Python World

# %% [markdown]
# # Ket thuc

# %%
# %run ex1_calc.py
# Out:
# Caculator Basic
# c = 2 + 3 = 5

# %%
import subprocess
subprocess.run(["python", "ex3_circle.py"], input="5\n", text=True)
